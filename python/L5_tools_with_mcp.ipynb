# %% [markdown]
# # Tools with MCP ⏰
#
# The Model Context Protocol (MCP) provides a standardized way to connect AI agents to external tools and data sources. Let's connect to an MCP server using `langchain-mcp-adapters`.

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables

# %%
from dotenv import load_dotenv
from env_utils import doublecheck_env

# Load environment variables from .env
load_dotenv()

# Check and print results
doublecheck_env("example.env")
# Out:
# OPENAI_API_KEY=****p0UA
# LANGSMITH_API_KEY=****77f2
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ials

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import nest_asyncio

nest_asyncio.apply()

# Connect to the mcp-time server for timezone-aware operations
# This Go-based server provides tools for current time, relative time parsing,
# timezone conversion, duration arithmetic, and time comparison
mcp_client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "npx",
            "args": ["-y", "@theo.foobar/mcp-time"],
        }
    },
)

# Load tools from the MCP server
mcp_tools = await mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")
# Out:
# Loaded 5 MCP tools: ['add_time', 'compare_time', 'convert_timezone', 'current_time', 'relative_time']

# %% [markdown]
# Create an agent with the MCP-provided time tools.

# %%
from langchain.agents import create_agent

agent_with_mcp = create_agent(
    model="openai:gpt-5",
    tools=mcp_tools,
    system_prompt="You are a helpful assistant",
)

# %% [markdown]
# Ask about the current time in San Francisco.

# %%
result = await agent_with_mcp.ainvoke(
    {"messages": [{"role": "user", "content": "What's the time in Australia right now?"}]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's the time in Australia right now?
# ================================== Ai Message ==================================
# Tool Calls:
#   current_time (call_ZPKjRZPGe6BwmfvidIho7mYY)
#  Call ID: call_ZPKjRZPGe6BwmfvidIho7mYY
#   Args:
#     format: Mon, 02 Jan 2006 15:04:05 Z07:00
#     timezone: Australia/Sydney
#   current_time (call_t8wIYXw4xxeYoIZfUqNrzXTy)
#  Call ID: call_t8wIYXw4xxeYoIZfUqNrzXTy
#   Args:
#     format: Mon, 02 Jan 2006 15:04:05 Z07:00
#     timezone: Australia/Brisbane
#   current_time (call_HmuwZQ2zp2bO7emoMHEpfaLJ)
#  Call ID: call_HmuwZQ2zp2bO7emoMHEpfaLJ
#   Args:
#     format: Mon, 02 Jan 2006 15:04:05 Z07:00
#     timezone: Australia/Adelaide
#   current_time (call_IHjTjqyAvsFZEyoWneO0zbwF)
#  Call ID: call_IHjTjqyAvsFZEyoWneO0zbwF
#   Args:
#     format: Mon, 02 Jan 2006 15:04:05 Z07:00
#     timezone: Australia/Darwin
#   current_time (call_MFlbYfTZnZrDCoTWYUjcu9cx)
#  Call ID: call_MFlbYfTZnZrDCoTWYUjcu9cx
#   Args:
#     format: Mon, 02 Jan 2006 15:04:05 Z07:00
#     timezone: Australia/Perth
# ================================= Tool Message =================================
# Name: current_time
#
# Sat, 29 Nov 2025 05:57:50 +11:00
# ================================= Tool Message =================================
# Name: current_time
#
# Sat, 29 Nov 2025 04:57:50 +10:00
# ================================= Tool Message =================================
# Name: current_time
#
# Sat, 29 Nov 2025 05:27:51 +10:30
# ================================= Tool Message =================================
# Name: current_time
#
# Sat, 29 Nov 2025 04:27:51 +09:30
# ================================= Tool Message =================================
# Name: current_time
#
# Sat, 29 Nov 2025 02:57:50 +08:00
# ================================== Ai Message ==================================
#
# Australia spans multiple time zones. Right now, the local times are approximately:
#
# - Sydney (NSW, ACT; AEDT): Sat, 29 Nov 2025 05:57:50 +11:00
# - Brisbane (QLD; AEST): Sat, 29 Nov 2025 04:57:50 +10:00
# - Adelaide (SA; ACDT): Sat, 29 Nov 2025 05:27:51 +10:30
# - Darwin (NT; ACST): Sat, 29 Nov 2025 04:27:51 +09:30
# - Perth (WA; AWST): Sat, 29 Nov 2025 02:57:50 +08:00
#
# If you tell me the specific Australian city or state, I can give you the exact local time there.
